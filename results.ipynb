# %% [markdown]
# # Results
# Di Tuccio Gianluca, Orsini Lorenzo

# %%
from tqdm import tqdm
from z3 import *
from numpy import random
import os
import pandas as pd



'''
SET HERE THE PATH OF THE MAIN FOLDER (i.e VLSI folder)
            |
            |
            V
'''

os.chdir('/Users/gianlucadituccio/Documents/VLSI')
from utils.utils import *

# %% [markdown]
# ## Models without Rotation

# %% [markdown]
# Let's have a look on some statistics about the four models:

# %%
results = pd.read_csv('utils/datasets/results.csv')
Statistics({'CP':results['time_CP'], 
            'SAT':results['time_SAT'],
            'SMT':results['time_SMT'],
            'MIP':results['time_MIP']}, 
           {'h_min':results['h_min'], 
            'CP':results['h_CP'], 
            'SAT':results['h_SAT'],
            'SMT':results['h_SMT'],
            'MIP':results['h_MIP']},
            timeout=300)
# Out:
# TIMEOUT is seen as 300s.
#
# +------------------+---------+----------+----------+----------+
# |                  |      CP |      SAT |      SMT |      MIP |
# +------------------+---------+----------+----------+----------+
# |  Total Time [s]  | 576.446 | 1684.761 | 2472.513 | 2815.366 |
# |     Max [s]      |   300.0 |    300.0 |    300.0 |    300.0 |
# |     Min [s]      |   0.163 |    0.061 |    0.026 |    0.007 |
# |     Mean [s]     |  14.411 |   42.119 |   61.813 |   70.384 |
# |     Std [s]      |  50.056 |   93.701 |   96.325 |  110.566 |
# | Instances Solved |   39/40 |    36/40 |    36/40 |    34/40 |
# |    Optimal H     |   39/40 |    36/40 |    36/40 |    34/40 |
# +------------------+---------+----------+----------+----------+

# %% [markdown]
# Then, let's see the number of minimums and maximums for each models (for each instance we've computed the min and the max, we count them and we've divided them by the first 20 instances and the last 20 instances):

# %%
res = results.drop(columns=['h_CP','h_SAT','h_SMT','h_MIP','h_min'])
res = res.rename(columns={'time_CP':'CP', 'time_SMT':'SMT', 'time_SAT':'SAT', 'time_MIP':'MIP'})
res = res.replace('TIMEOUT', 0)
res = res.astype(float)
res = res.reset_index(drop=True)
res = res.set_index("Instance")
Results(res, ['CP','SAT','SMT','MIP'])
# Out:
# +------------------------+-------+-------+-------+-------+
# |                        |    CP |   SAT |   SMT |   MIP |
# +------------------------+-------+-------+-------+-------+
# | Maximums (First Half)  |  3/20 |  9/20 |  5/20 |  3/20 |
# | Minimums (First Half)  | 11/20 |  0/20 |  0/20 |  9/20 |
# |  Timeout (First Half)  |  0/20 |  0/20 |  0/20 |  0/20 |
# |                        |       |       |       |       |
# | Maximums (Second Half) |  2/20 |  1/20 | 10/20 |  7/20 |
# | Minimums (Second Half) | 12/20 |  0/20 |  0/20 |  8/20 |
# | Timeout (Second Half)  |  1/20 |  4/20 |  4/20 |  6/20 |
# |                        |       |       |       |       |
# |     Total Minimums     | 23/40 |  0/40 |  0/40 | 17/40 |
# |     Total Maximums     |  5/40 | 10/40 | 15/40 | 10/40 |
# |     Total Timeout      |  1/40 |  4/40 |  4/40 |  6/40 |
# +------------------------+-------+-------+-------+-------+

# %%
res = res[['CP','SAT','SMT','MIP']]
res.style.apply(highlight_max, axis=1).apply(highlight_min, axis=1).set_properties(**{'border-top': '2px solid', 'border-bottom': '2px solid'}, axis=1)
# Out:
# <style  type="text/css" >
# #T_d5ccf_row0_col0,#T_d5ccf_row1_col0,#T_d5ccf_row2_col0,#T_d5ccf_row3_col1,#T_d5ccf_row4_col1,#T_d5ccf_row5_col1,#T_d5ccf_row6_col1,#T_d5ccf_row7_col1,#T_d5ccf_row8_col1,#T_d5ccf_row9_col1,#T_d5ccf_row10_col2,#T_d5ccf_row11_col2,#T_d5ccf_row12_col2,#T_d5ccf_row13_col1,#T_d5ccf_row14_col1,#T_d5ccf_row15_col3,#T_d5ccf_row16_col3,#T_d5ccf_row17_col2,#T_d5ccf_row18_col2,#T_d5ccf_row19_col3,#T_d5ccf_row20_col2,#T_d5ccf_row21_col2,#T_d5ccf_row22_col3,#T_d5ccf_row23_col2,#T_d5ccf_row24_col2,#T_d5ccf_row25_col3,#T_d5ccf_row26_col2,#T_d5ccf_row27_col3,#T_d5ccf_row28_col2,#T_d5ccf_row29_col2,#T_d5ccf_row30_col2,#T_d5ccf_row32_col2,#T_d5ccf_row33_col3,#T_d5ccf_row34_col3,#T_d5ccf_row35_col2,#T_d5ccf_row36_col1,#T_d5ccf_row38_col3{
#             background-color:  #F4F410;
#             border-top:  2px solid;
#             border-bottom:  2px solid;
#             axis:  1;
#         }#T_d5ccf_row0_col1,#T_d5ccf_row0_col2,#T_d5ccf_row1_col1,#T_d5ccf_row1_col2,#T_d5ccf_row2_col1,#T_d5ccf_row2_col2,#T_d5ccf_row3_col0,#T_d5ccf_row3_col2,#T_d5ccf_row4_col0,#T_d5ccf_row4_col2,#T_d5ccf_row5_col0,#T_d5ccf_row5_col2,#T_d5ccf_row6_col0,#T_d5ccf_row6_col2,#T_d5ccf_row7_col0,#T_d5ccf_row7_col2,#T_d5ccf_row8_col0,#T_d5ccf_row8_col2,#T_d5ccf_row9_col2,#T_d5ccf_row9_col3,#T_d5ccf_row10_col1,#T_d5ccf_row10_col3,#T_d5ccf_row11_col1,#T_d5ccf_row11_col3,#T_d5ccf_row12_col1,#T_d5ccf_row12_col3,#T_d5ccf_row13_col2,#T_d5ccf_row13_col3,#T_d5ccf_row14_col2,#T_d5ccf_row14_col3,#T_d5ccf_row15_col1,#T_d5ccf_row15_col2,#T_d5ccf_row16_col1,#T_d5ccf_row16_col2,#T_d5ccf_row17_col1,#T_d5ccf_row17_col3,#T_d5ccf_row18_col1,#T_d5ccf_row18_col3,#T_d5ccf_row19_col1,#T_d5ccf_row19_col2,#T_d5ccf_row20_col1,#T_d5ccf_row20_col3,#T_d5ccf_row21_col1,#T_d5ccf_row21_col3,#T_d5ccf_row22_col1,#T_d5ccf_row22_col2,#T_d5ccf_row23_col1,#T_d5ccf_row23_col3,#T_d5ccf_row24_col0,#T_d5ccf_row24_col1,#T_d5ccf_row25_col1,#T_d5ccf_row25_col2,#T_d5ccf_row26_col1,#T_d5ccf_row26_col3,#T_d5ccf_row27_col1,#T_d5ccf_row27_col2,#T_d5ccf_row28_col1,#T_d5ccf_row28_col3,#T_d5ccf_row29_col0,#T_d5ccf_row30_col0,#T_d5ccf_row30_col1,#T_d5ccf_row32_col1,#T_d5ccf_row32_col3,#T_d5ccf_row33_col1,#T_d5ccf_row33_col2,#T_d5ccf_row34_col1,#T_d5ccf_row34_col2,#T_d5ccf_row35_col0,#T_d5ccf_row35_col1,#T_d5ccf_row36_col0,#T_d5ccf_row38_col1,#T_d5ccf_row38_col2{
#             border-top:  2px solid;
#             border-bottom:  2px solid;
#             axis:  1;
#         }#T_d5ccf_row0_col3,#T_d5ccf_row1_col3,#T_d5ccf_row2_col3,#T_d5ccf_row3_col3,#T_d5ccf_row4_col3,#T_d5ccf_row5_col3,#T_d5ccf_row6_col3,#T_d5ccf_row7_col3,#T_d5ccf_row8_col3,#T_d5ccf_row9_col0,#T_d5ccf_row10_col0,#T_d5ccf_row11_col0,#T_d5ccf_row12_col0,#T_d5ccf_row13_col0,#T_d5ccf_row14_col0,#T_d5ccf_row15_col0,#T_d5ccf_row16_col0,#T_d5ccf_row17_col0,#T_d5ccf_row18_col0,#T_d5ccf_row19_col0,#T_d5ccf_row20_col0,#T_d5ccf_row21_col0,#T_d5ccf_row22_col0,#T_d5ccf_row23_col0,#T_d5ccf_row25_col0,#T_d5ccf_row26_col0,#T_d5ccf_row27_col0,#T_d5ccf_row28_col0,#T_d5ccf_row30_col3,#T_d5ccf_row31_col0,#T_d5ccf_row32_col0,#T_d5ccf_row33_col0,#T_d5ccf_row34_col0,#T_d5ccf_row35_col3,#T_d5ccf_row37_col0,#T_d5ccf_row38_col0{
#             background-color:  #90EE90;
#             border-top:  2px solid;
#             border-bottom:  2px solid;
#             axis:  1;
#         }#T_d5ccf_row24_col3,#T_d5ccf_row29_col1,#T_d5ccf_row29_col3,#T_d5ccf_row31_col1,#T_d5ccf_row31_col2,#T_d5ccf_row31_col3,#T_d5ccf_row36_col2,#T_d5ccf_row36_col3,#T_d5ccf_row37_col1,#T_d5ccf_row37_col2,#T_d5ccf_row37_col3{
#             background-color:  #F08080;
#             border-top:  2px solid;
#             border-bottom:  2px solid;
#             axis:  1;
#         }#T_d5ccf_row39_col0,#T_d5ccf_row39_col1,#T_d5ccf_row39_col2,#T_d5ccf_row39_col3{
#             background-color:  #F4F410;
#             background-color:  #F08080;
#             border-top:  2px solid;
#             border-bottom:  2px solid;
#             axis:  1;
#         }</style><table id="T_d5ccf_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >CP</th>        <th class="col_heading level0 col1" >SAT</th>        <th class="col_heading level0 col2" >SMT</th>        <th class="col_heading level0 col3" >MIP</th>    </tr>    <tr>        <th class="index_name level0" >Instance</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d5ccf_level0_row0" class="row_heading level0 row0" >1.0</th>
#                         <td id="T_d5ccf_row0_col0" class="data row0 col0" >0.164591</td>
#                         <td id="T_d5ccf_row0_col1" class="data row0 col1" >0.061015</td>
#                         <td id="T_d5ccf_row0_col2" class="data row0 col2" >0.026455</td>
#                         <td id="T_d5ccf_row0_col3" class="data row0 col3" >0.010768</td>
#             </tr>
#             <tr>
#                         <th id="T_d5ccf_level0_row1" class="row_heading level0 row1" >2.0</th>
#                         <td id="T_d5ccf_row1_col0" class="data row1 col0" >0.162945</td>
#                         <td id="T_d5ccf_row1_col1" class="data row1 col1" >0.088203</td>
#                         <td id="T_d5ccf_row1_col2" class="data row1 col2" >0.031472</td>
#                         <td id="T_d5ccf_row1_col3" class="data row1 col3" >0.006779</td>
#             </tr>
#             <tr>
#                         <th id="T_d5ccf_level0_row2" class="row_heading level0 row2" >3.0</th>
#                         <td id="T_d5ccf_row2_col0" class="data row2 col0" >0.164486</td>
#                         <td id="T_d5ccf_row2_col1" class="data row2 col1" >0.130407</td>
#                         <td id="T_d5ccf_row2_col2" class="data row2 col2" >0.045519</td>
#                         <td id="T_d5ccf_row2_col3" class="data row2 col3" >0.007412</td>
#             </tr>
#             <tr>
#                         <th id="T_d5ccf_level0_row3" class="row_heading level0 row3" >4.0</th>
#                         <td id="T_d5ccf_row3_col0" class="data row3 col0" >0.172714</td>
#                         <td id="T_d5ccf_row3_col1" class="data row3 col1" >0.191850</td>
#                         <td id="T_d5ccf_row3_col2" class="data row3 col2" >0.061873</td>
#                         <td id="T_d5ccf_row3_col3" class="data row3 col3" >0.008902</td>
#             </tr>
#             <tr>
#                         <th id="T_d5ccf_level0_row4" class="row_heading level0 row4" >5.0</th>
#                         <td id="T_d5ccf_row4_col0" class="data row4 col0" >0.173201</td>
#                         <td id="T_d5ccf_row4_col1" class="data row4 col1" >0.261224</td>
#                         <td id="T_d5ccf_row4_col2" class="data row4 col2" >0.105196</td>
#                         <td id="T_d5ccf_row4_col3" class="data row4 col3" >0.029125</td>
#             </tr>
#             <tr>
#                         <th id="T_d5ccf_level0_row5" class="row_heading level0 row5" >6.0</th>
#                         <td id="T_d5ccf_row5_col0" class="data row5 col0" >0.170079</td>
#                         <td id="T_d5ccf_row5_col1" class="data row5 col1" >0.360619</td>
#                         <td id="T_d5ccf_row5_col2" class="data row5 col2" >0.144190</td>
#                         <td id="T_d5ccf_row5_col3" class="data row5 col3" >0.013935</td>
#             </tr>
#             <tr>
#                         <th id="T_d5ccf_level0_row6" class="row_heading level0 row6" >7.0</th>
#                         <td id="T_d5ccf_row6_col0" class="data row6 col0" >0.171500</td>
#                         <td id="T_d5ccf_row6_col1" class="data row6 col1" >0.380923</td>
#                         <td id="T_d5ccf_row6_col2" class="data row6 col2" >0.186020</td>
#                         <td id="T_d5ccf_row6_col3" class="data row6 col3" >0.026313</td>
#             </tr>
#             <tr>
#                         <th id="T_d5ccf_level0_row7" class="row_heading level0 row7" >8.0</th>
#                         <td id="T_d5ccf_row7

# %% [markdown]
# ## Models with Rotation

# %%
results = pd.read_csv('utils/datasets/results_rotation.csv')
Statistics({'CP':results['time_CP'], 
            'SAT':results['time_SAT'],
            'SMT':results['time_SMT'],
            'MIP':results['time_MIP']}, 
           {'h_min':results['h_min'], 
            'CP':results['h_CP'], 
            'SAT':results['h_SAT'],
            'SMT':results['h_SMT'],
            'MIP':results['h_MIP']},
            timeout=300)
# Out:
# TIMEOUT is seen as 300s.
#
# +------------------+----------+----------+----------+----------+
# |                  |       CP |      SAT |      SMT |      MIP |
# +------------------+----------+----------+----------+----------+
# |  Total Time [s]  | 3725.503 | 3444.205 | 6000.952 | 4109.279 |
# |     Max [s]      |    300.0 |    300.0 |    300.0 |    300.0 |
# |     Min [s]      |    0.163 |    0.074 |    0.042 |    0.001 |
# |     Mean [s]     |   93.138 |   86.105 |  150.024 |  102.732 |
# |     Std [s]      |  131.409 |  115.012 |  129.653 |  134.659 |
# | Instances Solved |    29/40 |    33/40 |    28/40 |    28/40 |
# |    Optimal H     |    29/40 |    33/40 |    28/40 |    28/40 |
# +------------------+----------+----------+----------+----------+

# %%
res = results.drop(columns=['h_CP','h_SAT','h_SMT','h_MIP','h_min'])
res = res.rename(columns={'time_CP':'CP', 'time_SMT':'SMT', 'time_SAT':'SAT', 'time_MIP':'MIP'})
res = res.replace('TIMEOUT', 0)
res = res.astype(float)
res = res.reset_index(drop=True)
res = res.set_index("Instance")
Results(res, ['CP','SAT','SMT','MIP'])
# Out:
# +------------------------+-------+-------+-------+-------+
# |                        |    CP |   SAT |   SMT |   MIP |
# +------------------------+-------+-------+-------+-------+
# | Maximums (First Half)  |  2/20 |  6/20 | 12/20 |  0/20 |
# | Minimums (First Half)  |  6/20 |  1/20 |  0/20 | 13/20 |
# |  Timeout (First Half)  |  1/20 |  0/20 |  0/20 |  1/20 |
# |                        |       |       |       |       |
# | Maximums (Second Half) |  6/20 |  6/20 |  7/20 |  1/20 |
# | Minimums (Second Half) | 12/20 |  2/20 |  4/20 |  2/20 |
# | Timeout (Second Half)  | 10/20 |  7/20 | 12/20 | 11/20 |
# |                        |       |       |       |       |
# |     Total Minimums     | 18/40 |  3/40 |  4/40 | 15/40 |
# |     Total Maximums     |  8/40 | 12/40 | 19/40 |  1/40 |
# |     Total Timeout      | 11/40 |  7/40 | 12/40 | 12/40 |
# +------------------------+-------+-------+-------+-------+

# %%
res.style.apply(highlight_max, axis=1).apply(highlight_min, axis=1).set_properties(**{'border-top': '2px solid', 'border-bottom': '2px solid'}, axis=1)
# Out:
# <style  type="text/css" >
# #T_00861_row0_col0,#T_00861_row1_col0,#T_00861_row2_col1,#T_00861_row3_col1,#T_00861_row4_col1,#T_00861_row5_col2,#T_00861_row6_col1,#T_00861_row7_col1,#T_00861_row8_col1,#T_00861_row9_col2,#T_00861_row10_col2,#T_00861_row11_col2,#T_00861_row12_col2,#T_00861_row13_col2,#T_00861_row14_col2,#T_00861_row15_col2,#T_00861_row16_col2,#T_00861_row17_col2,#T_00861_row18_col2,#T_00861_row19_col2,#T_00861_row20_col1,#T_00861_row21_col1,#T_00861_row22_col2,#T_00861_row23_col2,#T_00861_row25_col0,#T_00861_row27_col2,#T_00861_row28_col3,#T_00861_row30_col2,#T_00861_row32_col2,#T_00861_row33_col2,#T_00861_row34_col1,#T_00861_row35_col2{
#             background-color:  #F4F410;
#             border-top:  2px solid;
#             border-bottom:  2px solid;
#             axis:  1;
#         }#T_00861_row0_col1,#T_00861_row0_col2,#T_00861_row1_col1,#T_00861_row1_col2,#T_00861_row2_col0,#T_00861_row2_col2,#T_00861_row3_col0,#T_00861_row3_col2,#T_00861_row4_col0,#T_00861_row4_col2,#T_00861_row5_col0,#T_00861_row5_col1,#T_00861_row6_col0,#T_00861_row6_col2,#T_00861_row7_col0,#T_00861_row7_col2,#T_00861_row8_col0,#T_00861_row8_col2,#T_00861_row9_col0,#T_00861_row9_col1,#T_00861_row10_col0,#T_00861_row10_col3,#T_00861_row11_col0,#T_00861_row11_col1,#T_00861_row12_col1,#T_00861_row12_col3,#T_00861_row13_col1,#T_00861_row13_col3,#T_00861_row14_col0,#T_00861_row14_col1,#T_00861_row15_col1,#T_00861_row15_col3,#T_00861_row16_col0,#T_00861_row16_col1,#T_00861_row17_col1,#T_00861_row17_col3,#T_00861_row18_col1,#T_00861_row18_col3,#T_00861_row19_col1,#T_00861_row20_col0,#T_00861_row20_col2,#T_00861_row21_col0,#T_00861_row21_col3,#T_00861_row22_col0,#T_00861_row22_col1,#T_00861_row23_col1,#T_00861_row23_col3,#T_00861_row25_col1,#T_00861_row27_col1,#T_00861_row27_col3,#T_00861_row28_col0,#T_00861_row28_col1,#T_00861_row30_col1,#T_00861_row30_col3,#T_00861_row32_col1,#T_00861_row32_col3,#T_00861_row33_col0,#T_00861_row33_col3,#T_00861_row34_col0,#T_00861_row35_col0{
#             border-top:  2px solid;
#             border-bottom:  2px solid;
#             axis:  1;
#         }#T_00861_row0_col3,#T_00861_row1_col3,#T_00861_row2_col3,#T_00861_row3_col3,#T_00861_row4_col3,#T_00861_row5_col3,#T_00861_row6_col3,#T_00861_row7_col3,#T_00861_row8_col3,#T_00861_row9_col3,#T_00861_row10_col1,#T_00861_row11_col3,#T_00861_row12_col0,#T_00861_row13_col0,#T_00861_row14_col3,#T_00861_row15_col0,#T_00861_row16_col3,#T_00861_row17_col0,#T_00861_row18_col0,#T_00861_row20_col3,#T_00861_row22_col3,#T_00861_row23_col0,#T_00861_row26_col1,#T_00861_row29_col1,#T_00861_row30_col0,#T_00861_row37_col1{
#             background-color:  #90EE90;
#             border-top:  2px solid;
#             border-bottom:  2px solid;
#             axis:  1;
#         }#T_00861_row19_col0,#T_00861_row19_col3,#T_00861_row21_col2,#T_00861_row25_col2,#T_00861_row25_col3,#T_00861_row26_col0,#T_00861_row26_col2,#T_00861_row26_col3,#T_00861_row27_col0,#T_00861_row28_col2,#T_00861_row29_col0,#T_00861_row29_col2,#T_00861_row29_col3,#T_00861_row32_col0,#T_00861_row33_col1,#T_00861_row34_col2,#T_00861_row34_col3,#T_00861_row35_col1,#T_00861_row35_col3,#T_00861_row37_col0,#T_00861_row37_col2,#T_00861_row37_col3{
#             background-color:  #F08080;
#             border-top:  2px solid;
#             border-bottom:  2px solid;
#             axis:  1;
#         }#T_00861_row24_col0,#T_00861_row24_col1,#T_00861_row24_col2,#T_00861_row24_col3,#T_00861_row31_col0,#T_00861_row31_col1,#T_00861_row31_col2,#T_00861_row31_col3,#T_00861_row36_col0,#T_00861_row36_col1,#T_00861_row36_col2,#T_00861_row36_col3,#T_00861_row38_col0,#T_00861_row38_col1,#T_00861_row38_col2,#T_00861_row38_col3,#T_00861_row39_col0,#T_00861_row39_col1,#T_00861_row39_col2,#T_00861_row39_col3{
#             background-color:  #F4F410;
#             background-color:  #F08080;
#             border-top:  2px solid;
#             border-bottom:  2px solid;
#             axis:  1;
#         }</style><table id="T_00861_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >CP</th>        <th class="col_heading level0 col1" >SAT</th>        <th class="col_heading level0 col2" >SMT</th>        <th class="col_heading level0 col3" >MIP</th>    </tr>    <tr>        <th class="index_name level0" >Instance</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_00861_level0_row0" class="row_heading level0 row0" >1.0</th>
#                         <td id="T_00861_row0_col0" class="data row0 col0" >0.165624</td>
#                         <td id="T_00861_row0_col1" class="data row0 col1" >0.074252</td>
#                         <td id="T_00861_row0_col2" class="data row0 col2" >0.061151</td>
#                         <td id="T_00861_row0_col3" class="data row0 col3" >0.001419</td>
#             </tr>
#             <tr>
#                         <th id="T_00861_level0_row1" class="row_heading level0 row1" >2.0</th>
#                         <td id="T_00861_row1_col0" class="data row1 col0" >0.164263</td>
#                         <td id="T_00861_row1_col1" class="data row1 col1" >0.106322</td>
#                         <td id="T_00861_row1_col2" class="data row1 col2" >0.042045</td>
#                         <td id="T_00861_row1_col3" class="data row1 col3" >0.002671</td>
#             </tr>
#             <tr>
#                         <th id="T_00861_level0_row2" class="row_heading level0 row2" >3.0</th>
#                         <td id="T_00861_row2_col0" class="data row2 col0" >0.163071</td>
#                         <td id="T_00861_row2_col1" class="data row2 col1" >0.163967</td>
#                         <td id="T_00861_row2_col2" class="data row2 col2" >0.062172</td>
#                         <td id="T_00861_row2_col3" class="data row2 col3" >0.001893</td>
#             </tr>
#             <tr>
#                         <th id="T_00861_level0_row3" class="row_heading level0 row3" >4.0</th>
#                         <td id="T_00861_row3_col0" class="data row3 col0" >0.169214</td>
#                         <td id="T_00861_row3_col1" class="data row3 col1" >1.027223</td>
#                         <td id="T_00861_row3_col2" class="data row3 col2" >0.110308</td>
#                         <td id="T_00861_row3_col3" class="data row3 col3" >0.006430</td>
#             </tr>
#             <tr>
#                         <th id="T_00861_level0_row4" class="row_heading level0 row4" >5.0</th>
#                         <td id="T_00861_row4_col0" class="data row4 col0" >0.203163</td>
#                         <td id="T_00861_row4_col1" class="data row4 col1" >0.380429</td>
#                         <td id="T_00861_row4_col2" class="data row4 col2" >0.136655</td>
#                         <td id="T_00861_row4_col3" class="data row4 col3" >0.065152</td>
#             </tr>
#             <tr>
#                         <th id="T_00861_level0_row5" class="row_heading level0 row5" >6.0</th>
#                         <td id="T_00861_row5_col0" class="data row5 col0" >0.242367</td>
#                         <td id="T_00861_row5_col1" class="data row5 col1" >0.492484</td>
#                         <td id="T_00861_row5_col2" class="data row5 col2" >0.554974</td>
#                         <td id="T_00861_row5_col3" class="data row5 col3" >0.010547</td>
#             </tr>
#             <tr>
#                         <th id="T_00861_level0_row6" class="row_heading level0 row6" >7.0</th>
#                         <td id="T_00861_row6_col0" class="data row6 col0" >0.454942</td>
#                         <td id="T_00861_row6_col1" class="data row6 col1" >0.554528</td>
#                         <td id="T_00861_row6_col2" class="data row6 col2" >0.525837</td>
#                         <td id="T_00861_row6_col3" class="data row6 col3" >0.088373</td>
#             </tr>
#             <tr>
#                         <th id="T_00861_level0_row7" class="row_heading level0 row7" >8.0</th>
#                         <td id="T_00861_row7
