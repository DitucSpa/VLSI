# %% [markdown]
# # Results
# Di Tuccio Gianluca, Orsini Lorenzo

# %%
from tqdm import tqdm
from z3 import *
from numpy import random
import os
import pandas as pd
from utils.utils import *

# %% [markdown]
# ## Models without Rotation

# %% [markdown]
# Let's have a look on some statistics about the four models:

# %%
results = pd.read_csv('utils/datasets/results.csv')
Statistics({'CP + SB w/out R':results['CP + SB w/out R'], 
            'SAT + SB w/out R':results['SAT + SB w/out R'],
            'SMT + SB w/out R':results['SMT + SB w/out R'],
            'MIP + SB w/out R':results['MIP + SB w/out R']},
            timeout=300)
results = results.replace('TIMEOUT', 0)
results = results.astype(float)
results = results.reset_index(drop=True)
results = results.set_index("Instance")
print()
print('GREEN --> BEST VALUE,\nYELLOW --> WORST VALUE,\nRED --> TIMEOUT')
results.style.apply(highlight_max, axis=1).apply(highlight_min, axis=1).apply(highlight_timeout, axis=1).set_properties(**{'border-top': '2px solid', 'border-bottom': '2px solid'}, axis=1)
# Out:
# TIMEOUT is seen as 300s.
#
# +------------------+-----------------+------------------+------------------+------------------+
# |                  | CP + SB w/out R | SAT + SB w/out R | SMT + SB w/out R | MIP + SB w/out R |
# +------------------+-----------------+------------------+------------------+------------------+
# |  Total Time [s]  |         491.659 |          993.825 |         2060.039 |         2504.815 |
# |     Max [s]      |           300.0 |            300.0 |            300.0 |            300.0 |
# |     Min [s]      |           0.161 |            0.043 |            0.035 |            0.002 |
# |     Mean [s]     |          12.291 |           24.846 |           51.501 |            62.62 |
# |     Std [s]      |          48.287 |           71.622 |           99.084 |          113.628 |
# | Instances Solved |           39/40 |            38/40 |            35/40 |            33/40 |
# +------------------+-----------------+------------------+------------------+------------------+
#
# GREEN --> BEST VALUE,
# YELLOW --> WORST VALUE,
# RED --> TIMEOUT
# <style  type="text/css" >
# #T_84901_row0_col0,#T_84901_row1_col0,#T_84901_row2_col0,#T_84901_row3_col0,#T_84901_row4_col0,#T_84901_row5_col1,#T_84901_row6_col1,#T_84901_row7_col1,#T_84901_row8_col1,#T_84901_row9_col1,#T_84901_row10_col2,#T_84901_row11_col1,#T_84901_row12_col1,#T_84901_row13_col2,#T_84901_row14_col2,#T_84901_row15_col3,#T_84901_row16_col2,#T_84901_row17_col2,#T_84901_row18_col3,#T_84901_row19_col2,#T_84901_row20_col3,#T_84901_row21_col2,#T_84901_row22_col2,#T_84901_row23_col2,#T_84901_row24_col2,#T_84901_row25_col2,#T_84901_row26_col2,#T_84901_row27_col2,#T_84901_row28_col2,#T_84901_row29_col3,#T_84901_row30_col2,#T_84901_row31_col1,#T_84901_row32_col2,#T_84901_row33_col3,#T_84901_row34_col2,#T_84901_row35_col3,#T_84901_row36_col2,#T_84901_row38_col1{
#             background-color:  #F4F410;
#             border-top:  2px solid;
#             border-bottom:  2px solid;
#             axis:  1;
#         }#T_84901_row0_col1,#T_84901_row0_col2,#T_84901_row1_col1,#T_84901_row1_col2,#T_84901_row2_col1,#T_84901_row2_col2,#T_84901_row3_col1,#T_84901_row3_col2,#T_84901_row4_col1,#T_84901_row4_col2,#T_84901_row5_col0,#T_84901_row5_col2,#T_84901_row6_col0,#T_84901_row6_col2,#T_84901_row7_col0,#T_84901_row7_col2,#T_84901_row8_col0,#T_84901_row8_col2,#T_84901_row9_col0,#T_84901_row9_col2,#T_84901_row10_col0,#T_84901_row10_col1,#T_84901_row11_col0,#T_84901_row11_col2,#T_84901_row12_col0,#T_84901_row12_col2,#T_84901_row13_col0,#T_84901_row13_col1,#T_84901_row14_col0,#T_84901_row14_col1,#T_84901_row15_col1,#T_84901_row15_col2,#T_84901_row16_col0,#T_84901_row16_col1,#T_84901_row17_col1,#T_84901_row17_col3,#T_84901_row18_col1,#T_84901_row18_col2,#T_84901_row19_col1,#T_84901_row19_col3,#T_84901_row20_col1,#T_84901_row20_col2,#T_84901_row21_col1,#T_84901_row21_col3,#T_84901_row22_col0,#T_84901_row22_col1,#T_84901_row23_col0,#T_84901_row23_col1,#T_84901_row24_col1,#T_84901_row25_col1,#T_84901_row25_col3,#T_84901_row26_col1,#T_84901_row26_col3,#T_84901_row27_col1,#T_84901_row27_col3,#T_84901_row28_col1,#T_84901_row28_col3,#T_84901_row29_col1,#T_84901_row30_col1,#T_84901_row30_col3,#T_84901_row32_col0,#T_84901_row32_col1,#T_84901_row33_col1,#T_84901_row33_col2,#T_84901_row34_col1,#T_84901_row35_col1,#T_84901_row35_col2,#T_84901_row36_col0{
#             border-top:  2px solid;
#             border-bottom:  2px solid;
#             axis:  1;
#         }#T_84901_row0_col3,#T_84901_row1_col3,#T_84901_row2_col3,#T_84901_row3_col3,#T_84901_row4_col3,#T_84901_row5_col3,#T_84901_row6_col3,#T_84901_row7_col3,#T_84901_row8_col3,#T_84901_row9_col3,#T_84901_row10_col3,#T_84901_row11_col3,#T_84901_row12_col3,#T_84901_row13_col3,#T_84901_row14_col3,#T_84901_row15_col0,#T_84901_row16_col3,#T_84901_row17_col0,#T_84901_row18_col0,#T_84901_row19_col0,#T_84901_row20_col0,#T_84901_row21_col0,#T_84901_row22_col3,#T_84901_row23_col3,#T_84901_row24_col0,#T_84901_row25_col0,#T_84901_row26_col0,#T_84901_row27_col0,#T_84901_row28_col0,#T_84901_row29_col0,#T_84901_row30_col0,#T_84901_row31_col0,#T_84901_row32_col3,#T_84901_row33_col0,#T_84901_row34_col0,#T_84901_row35_col0,#T_84901_row36_col1,#T_84901_row38_col0{
#             background-color:  #90EE90;
#             border-top:  2px solid;
#             border-bottom:  2px solid;
#             axis:  1;
#         }#T_84901_row24_col3,#T_84901_row29_col2,#T_84901_row31_col2,#T_84901_row31_col3,#T_84901_row34_col3,#T_84901_row36_col3,#T_84901_row37_col1,#T_84901_row37_col2,#T_84901_row37_col3,#T_84901_row38_col2,#T_84901_row38_col3{
#             background-color:  #F08080;
#             border-top:  2px solid;
#             border-bottom:  2px solid;
#             axis:  1;
#         }#T_84901_row37_col0{
#             background-color:  #90EE90;
#             background-color:  #90EE90;
#             border-top:  2px solid;
#             border-bottom:  2px solid;
#             axis:  1;
#         }#T_84901_row39_col0,#T_84901_row39_col1,#T_84901_row39_col2,#T_84901_row39_col3{
#             background-color:  #F4F410;
#             background-color:  #F08080;
#             border-top:  2px solid;
#             border-bottom:  2px solid;
#             axis:  1;
#         }</style><table id="T_84901_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >CP + SB w/out R</th>        <th class="col_heading level0 col1" >SAT + SB w/out R</th>        <th class="col_heading level0 col2" >SMT + SB w/out R</th>        <th class="col_heading level0 col3" >MIP + SB w/out R</th>    </tr>    <tr>        <th class="index_name level0" >Instance</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_84901_level0_row0" class="row_heading level0 row0" >1.0</th>
#                         <td id="T_84901_row0_col0" class="data row0 col0" >0.161359</td>
#                         <td id="T_84901_row0_col1" class="data row0 col1" >0.043063</td>
#                         <td id="T_84901_row0_col2" class="data row0 col2" >0.035216</td>
#                         <td id="T_84901_row0_col3" class="data row0 col3" >0.008457</td>
#             </tr>
#             <tr>
#                         <th id="T_84901_level0_row1" class="row_heading level0 row1" >2.0</th>
#                         <td id="T_84901_row1_col0" class="data row1 col0" >0.169902</td>
#                         <td id="T_84901_row1_col1" class="data row1 col1" >0.051413</td>
#                         <td id="T_84901_row1_col2" class="data row1 col2" >0.038764</td>
#                         <td id="T_84901_row1_col3" class="data row1 col3" >0.002499</td>
#             </tr>
#             <tr>
#                         <th id="T_84901_level0_row2" class="row_heading level0 row2" >3.0</th>
#                         <td id="T_84901_row2_col0" class="data row2 col0" >0.170856</td>
#                         <td id="T_84901_row2_col1" class="data row2 col1" >0.077347</td>
#                         <td id="T_84901_row2_col2" class="data row2 col2" >0.054940</td>
#                         <td id="T_84901_row2_col3" class="data row2 col3" >0.006792</td>
#             </tr>
#             <tr>
#                         <th id="T_84901_level0_row3" class="row_heading level0 row3" >4.0</th>
#                         <td id="T_84901_row3_col0" class="data row3 col0" >0.167597</td>
#                         <td id="T_84901_row3_col1" class="data row3 col1" >0.108347</td>
#                         <td id="T_84901_row3_col2" class="data row3 col2" >0.067312</td>
#                         <td id="T_84901_row3_col3" class="data row3 col3" >0.005207</td>
#             </tr>
#             <tr>
#                         <th id="T_84901_level0_row4" class="row_heading level0 row4" >5.0</th>
#                         <td id="T_84901_row4_col0" class="data row4 col0" >0.170944</td>
#                         <td id="T_84901_row4_col1" class="data row4 col1" >0.148188</td>
#                         <td id="T_84901_row4_col2" class="data row4 col2" >0.098915</td>
#                         <td id="T_84901_row4_col3" class="data row4 col3" >0.005924</td>
#             </tr>
#             <tr>
#                         <th id="T_84901_level0_row5" class="row_heading level0 row5" >6.0</th>
#                         <td id="T_84901_row5_col0" class="data row5 col0" >0.177056</td>
#                         <td id="T_84901_row5_col1" class="data row5 col1" >0.231296</td>
#                         <td id="T_84901_row5_col2" class="data row5 col2" >0.128067</td>
#                         <td id="T_84901_row5_col3" class="data row5 col3" >0.003089</td>
#             </tr>
#             <tr>
#                         <th id="T_84901_level0_row6" class="row_heading level0 row6" >7.0</th>
#                         <td id="T_84901_row6_col0" class="data row6 col0" >0.175173</td>
#                         <td id="T_84901_row6_col1" class="data row6 col1" >0.218975</td>
#                         <td id="T_84901_row6_col2" class="data row6 col2" >0.139224</td>

# %% [markdown]
# Then, let's see the number of minimums and maximums for each models (for each instance we've computed the min and the max, we count them and we've divided them by the first 20 instances and the last 20 instances):

# %%
Results(results, ['CP + SB w/out R','SAT + SB w/out R','SMT + SB w/out R','MIP + SB w/out R'])
# Out:
# +------------------------+-----------------+------------------+------------------+------------------+
# |                        | CP + SB w/out R | SAT + SB w/out R | SMT + SB w/out R | MIP + SB w/out R |
# +------------------------+-----------------+------------------+------------------+------------------+
# | Maximums (First Half)  |            5/20 |             7/20 |             6/20 |             2/20 |
# | Minimums (First Half)  |            4/20 |             0/20 |             0/20 |            16/20 |
# |  Timeout (First Half)  |            0/20 |             0/20 |             0/20 |             0/20 |
# |                        |                 |                  |                  |                  |
# | Maximums (Second Half) |            2/20 |             2/20 |            12/20 |             4/20 |
# | Minimums (Second Half) |           10/20 |             1/20 |             3/20 |             6/20 |
# | Timeout (Second Half)  |            1/20 |             2/20 |             5/20 |             7/20 |
# |                        |                 |                  |                  |                  |
# |     Total Minimums     |           14/40 |             1/40 |             3/40 |            22/40 |
# |     Total Maximums     |            7/40 |             9/40 |            18/40 |             6/40 |
# |     Total Timeout      |            1/40 |             2/40 |             5/40 |             7/40 |
# +------------------------+-----------------+------------------+------------------+------------------+

# %% [markdown]
# ## Models with Rotation

# %%
results = pd.read_csv('utils/datasets/results_rotation.csv')
Statistics({'CP + SB + R':results['CP + SB + R'], 
            'SAT + SB + R':results['SAT + SB + R'],
            'SMT + SB + R':results['SMT + SB + R'],
            'MIP + SB + R':results['MIP + SB + R']},
            timeout=300)
results = results.replace('TIMEOUT', 0)
results = results.astype(float)
results = results.reset_index(drop=True)
results = results.set_index("Instance")
print()
print('GREEN --> BEST VALUE,\nYELLOW --> WORST VALUE,\nRED --> TIMEOUT')
results.style.apply(highlight_max, axis=1).apply(highlight_min, axis=1).apply(highlight_timeout, axis=1).set_properties(**{'border-top': '2px solid', 'border-bottom': '2px solid'}, axis=1)
# Out:
# TIMEOUT is seen as 300s.
#
# +------------------+-------------+--------------+--------------+--------------+
# |                  | CP + SB + R | SAT + SB + R | SMT + SB + R | MIP + SB + R |
# +------------------+-------------+--------------+--------------+--------------+
# |  Total Time [s]  |    1984.004 |     2433.407 |     3870.686 |     4838.492 |
# |     Max [s]      |       300.0 |        300.0 |        300.0 |        300.0 |
# |     Min [s]      |       0.162 |        0.134 |        0.047 |        0.002 |
# |     Mean [s]     |        49.6 |       60.835 |       96.767 |      120.962 |
# |     Std [s]      |      97.914 |      101.056 |      134.332 |      136.516 |
# | Instances Solved |       36/40 |        36/40 |        29/40 |        27/40 |
# +------------------+-------------+--------------+--------------+--------------+
#
# GREEN --> BEST VALUE,
# YELLOW --> WORST VALUE,
# RED --> TIMEOUT
# <style  type="text/css" >
# #T_edec1_row0_col0,#T_edec1_row1_col1,#T_edec1_row2_col1,#T_edec1_row3_col1,#T_edec1_row4_col1,#T_edec1_row5_col1,#T_edec1_row6_col1,#T_edec1_row7_col1,#T_edec1_row8_col1,#T_edec1_row9_col1,#T_edec1_row10_col1,#T_edec1_row11_col1,#T_edec1_row12_col1,#T_edec1_row13_col1,#T_edec1_row14_col1,#T_edec1_row15_col3,#T_edec1_row16_col3,#T_edec1_row17_col1,#T_edec1_row18_col2,#T_edec1_row19_col1,#T_edec1_row20_col1,#T_edec1_row21_col2,#T_edec1_row22_col2,#T_edec1_row23_col1,#T_edec1_row25_col3,#T_edec1_row26_col2,#T_edec1_row27_col3,#T_edec1_row28_col3,#T_edec1_row29_col1,#T_edec1_row30_col2,#T_edec1_row32_col0,#T_edec1_row33_col3,#T_edec1_row34_col3,#T_edec1_row35_col3,#T_edec1_row38_col0{
#             background-color:  #F4F410;
#             border-top:  2px solid;
#             border-bottom:  2px solid;
#             axis:  1;
#         }#T_edec1_row0_col1,#T_edec1_row0_col2,#T_edec1_row1_col0,#T_edec1_row1_col2,#T_edec1_row2_col0,#T_edec1_row2_col2,#T_edec1_row3_col0,#T_edec1_row3_col2,#T_edec1_row4_col0,#T_edec1_row4_col2,#T_edec1_row5_col0,#T_edec1_row5_col2,#T_edec1_row6_col0,#T_edec1_row6_col2,#T_edec1_row7_col0,#T_edec1_row7_col2,#T_edec1_row8_col0,#T_edec1_row8_col2,#T_edec1_row9_col0,#T_edec1_row9_col3,#T_edec1_row10_col0,#T_edec1_row10_col2,#T_edec1_row11_col0,#T_edec1_row11_col3,#T_edec1_row12_col0,#T_edec1_row12_col2,#T_edec1_row13_col0,#T_edec1_row13_col2,#T_edec1_row14_col0,#T_edec1_row14_col2,#T_edec1_row15_col1,#T_edec1_row15_col2,#T_edec1_row16_col1,#T_edec1_row16_col2,#T_edec1_row17_col2,#T_edec1_row18_col1,#T_edec1_row20_col2,#T_edec1_row21_col1,#T_edec1_row22_col1,#T_edec1_row23_col0,#T_edec1_row23_col2,#T_edec1_row25_col1,#T_edec1_row25_col2,#T_edec1_row26_col1,#T_edec1_row26_col3,#T_edec1_row27_col1,#T_edec1_row27_col2,#T_edec1_row28_col1,#T_edec1_row28_col2,#T_edec1_row30_col1,#T_edec1_row30_col3,#T_edec1_row32_col1,#T_edec1_row32_col2,#T_edec1_row33_col1,#T_edec1_row34_col1,#T_edec1_row35_col1{
#             border-top:  2px solid;
#             border-bottom:  2px solid;
#             axis:  1;
#         }#T_edec1_row0_col3,#T_edec1_row1_col3,#T_edec1_row2_col3,#T_edec1_row3_col3,#T_edec1_row4_col3,#T_edec1_row5_col3,#T_edec1_row6_col3,#T_edec1_row7_col3,#T_edec1_row8_col3,#T_edec1_row9_col2,#T_edec1_row10_col3,#T_edec1_row11_col2,#T_edec1_row12_col3,#T_edec1_row13_col3,#T_edec1_row14_col3,#T_edec1_row15_col0,#T_edec1_row16_col0,#T_edec1_row17_col0,#T_edec1_row18_col0,#T_edec1_row19_col0,#T_edec1_row20_col0,#T_edec1_row21_col0,#T_edec1_row22_col0,#T_edec1_row23_col3,#T_edec1_row25_col0,#T_edec1_row26_col0,#T_edec1_row27_col0,#T_edec1_row28_col0,#T_edec1_row29_col0,#T_edec1_row30_col0,#T_edec1_row32_col3,#T_edec1_row33_col0,#T_edec1_row34_col0,#T_edec1_row35_col0,#T_edec1_row38_col1{
#             background-color:  #90EE90;
#             border-top:  2px solid;
#             border-bottom:  2px solid;
#             axis:  1;
#         }#T_edec1_row17_col3,#T_edec1_row18_col3,#T_edec1_row19_col2,#T_edec1_row19_col3,#T_edec1_row20_col3,#T_edec1_row21_col3,#T_edec1_row22_col3,#T_edec1_row24_col1,#T_edec1_row24_col2,#T_edec1_row24_col3,#T_edec1_row29_col2,#T_edec1_row29_col3,#T_edec1_row33_col2,#T_edec1_row34_col2,#T_edec1_row35_col2,#T_edec1_row37_col0,#T_edec1_row37_col2,#T_edec1_row37_col3,#T_edec1_row38_col2,#T_edec1_row38_col3{
#             background-color:  #F08080;
#             border-top:  2px solid;
#             border-bottom:  2px solid;
#             axis:  1;
#         }#T_edec1_row24_col0,#T_edec1_row37_col1{
#             background-color:  #90EE90;
#             background-color:  #90EE90;
#             border-top:  2px solid;
#             border-bottom:  2px solid;
#             axis:  1;
#         }#T_edec1_row31_col0,#T_edec1_row31_col1,#T_edec1_row31_col2,#T_edec1_row31_col3,#T_edec1_row36_col0,#T_edec1_row36_col1,#T_edec1_row36_col2,#T_edec1_row36_col3,#T_edec1_row39_col0,#T_edec1_row39_col1,#T_edec1_row39_col2,#T_edec1_row39_col3{
#             background-color:  #F4F410;
#             background-color:  #F08080;
#             border-top:  2px solid;
#             border-bottom:  2px solid;
#             axis:  1;
#         }</style><table id="T_edec1_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >CP + SB + R</th>        <th class="col_heading level0 col1" >SAT + SB + R</th>        <th class="col_heading level0 col2" >SMT + SB + R</th>        <th class="col_heading level0 col3" >MIP + SB + R</th>    </tr>    <tr>        <th class="index_name level0" >Instance</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_edec1_level0_row0" class="row_heading level0 row0" >1.0</th>
#                         <td id="T_edec1_row0_col0" class="data row0 col0" >0.162390</td>
#                         <td id="T_edec1_row0_col1" class="data row0 col1" >0.134470</td>
#                         <td id="T_edec1_row0_col2" class="data row0 col2" >0.052720</td>
#                         <td id="T_edec1_row0_col3" class="data row0 col3" >0.001950</td>
#             </tr>
#             <tr>
#                         <th id="T_edec1_level0_row1" class="row_heading level0 row1" >2.0</th>
#                         <td id="T_edec1_row1_col0" class="data row1 col0" >0.168664</td>
#                         <td id="T_edec1_row1_col1" class="data row1 col1" >0.173686</td>
#                         <td id="T_edec1_row1_col2" class="data row1 col2" >0.047450</td>
#                         <td id="T_edec1_row1_col3" class="data row1 col3" >0.004301</td>
#             </tr>
#             <tr>
#                         <th id="T_edec1_level0_row2" class="row_heading level0 row2" >3.0</th>
#                         <td id="T_edec1_row2_col0" class="data row2 col0" >0.167628</td>
#                         <td id="T_edec1_row2_col1" class="data row2 col1" >0.273914</td>
#                         <td id="T_edec1_row2_col2" class="data row2 col2" >0.067034</td>
#                         <td id="T_edec1_row2_col3" class="data row2 col3" >0.006159</td>
#             </tr>
#             <tr>
#                         <th id="T_edec1_level0_row3" class="row_heading level0 row3" >4.0</th>
#                         <td id="T_edec1_row3_col0" class="data row3 col0" >0.176315</td>
#                         <td id="T_edec1_row3_col1" class="data row3 col1" >0.417122</td>
#                         <td id="T_edec1_row3_col2" class="data row3 col2" >0.091781</td>
#                         <td id="T_edec1_row3_col3" class="data row3 col3" >0.008328</td>
#             </tr>
#             <tr>
#                         <th id="T_edec1_level0_row4" class="row_heading level0 row4" >5.0</th>
#                         <td id="T_edec1_row4_col0" class="data row4 col0" >0.247306</td>
#                         <td id="T_edec1_row4_col1" class="data row4 col1" >0.586453</td>
#                         <td id="T_edec1_row4_col2" class="data row4 col2" >0.127041</td>
#                         <td id="T_edec1_row4_col3" class="data row4 col3" >0.011513</td>
#             </tr>
#             <tr>
#                         <th id="T_edec1_level0_row5" class="row_heading level0 row5" >6.0</th>
#                         <td id="T_edec1_row5_col0" class="data row5 col0" >0.335286</td>
#                         <td id="T_edec1_row5_col1" class="data row5 col1" >0.837349</td>
#                         <td id="T_edec1_row5_col2" class="data row5 col2" >0.178411</td>
#                         <td id="T_edec1_row5_col3" class="data row5 col3" >0.003880</td>
#             </tr>
#             <tr>
#                         <th id="T_edec1_level0_row6" class="row_heading level0 row6" >7.0</th>
#                         <td id="T_edec1_row6_col0" class="data row6 col0" >0.293460</td>
#                         <td id="T_edec1_row6_col1" class="data row6 col1" >1.138929</td>
#                         <td id="T_edec1_row6_col2" class="data row6 col2" >0.174842</td>
#                         <td id="T_edec1_

# %%
Results(results, ['CP + SB + R','SAT + SB + R','SMT + SB + R','MIP + SB + R'])
# Out:
# +------------------------+-------------+--------------+--------------+--------------+
# |                        | CP + SB + R | SAT + SB + R | SMT + SB + R | MIP + SB + R |
# +------------------------+-------------+--------------+--------------+--------------+
# | Maximums (First Half)  |        1/20 |        16/20 |         1/20 |         2/20 |
# | Minimums (First Half)  |        2/20 |         0/20 |         3/20 |        15/20 |
# |  Timeout (First Half)  |        0/20 |         0/20 |         1/20 |         3/20 |
# |                        |             |              |              |              |
# | Maximums (Second Half) |        6/20 |         4/20 |         4/20 |         6/20 |
# | Minimums (Second Half) |        9/20 |         1/20 |         5/20 |         5/20 |
# | Timeout (Second Half)  |        4/20 |         4/20 |        10/20 |        10/20 |
# |                        |             |              |              |              |
# |     Total Minimums     |       11/40 |         1/40 |         8/40 |        20/40 |
# |     Total Maximums     |        7/40 |        20/40 |         5/40 |         8/40 |
# |     Total Timeout      |        4/40 |         4/40 |        11/40 |        13/40 |
# +------------------------+-------------+--------------+--------------+--------------+
